# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/world_population.csv')

# %%
df.head(10)
# Out:
#    Rank CCA3              Country           Capital      Continent  \
# 0    36  AFG          Afghanistan             Kabul           Asia
# 1   138  ALB              Albania            Tirana         Europe
# 2    34  DZA              Algeria           Algiers         Africa
# 3   213  ASM       American Samoa         Pago Pago        Oceania
# 4   203  AND              Andorra  Andorra la Vella         Europe
# 5    42  AGO               Angola            Luanda         Africa
# 6   224  AIA             Anguilla        The Valley  North America
# 7   201  ATG  Antigua and Barbuda      Saint John’s  North America
# 8    33  ARG            Argentina      Buenos Aires  South America
# 9   140  ARM              Armenia           Yerevan           Asia
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 0       41128771.0       38972230.0       33753499.0       28189672.0
# 1        2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
df['Rank']
# Out:
# 0       36
# 1      138
# 2       34
# 3      213
# 4      203
#       ...
# 229    226
# 230    172
# 231     46
# 232     63
# 233     74
# Name: Rank, Length: 234, dtype: int64

# %%
df_sorted = df.sort_values(by="Rank", ascending=True)
print(df_sorted['Rank'].head(10))
# Out:
# 41      1
# 92      2
# 221     3
# 93      4
# 156     5
# 149     6
# 27      7
# 16      8
# 171     9
# 131    10
# Name: Rank, dtype: int64

# %%
df.loc[3]
# Out:
# Rank                                      213
# CCA3                                      ASM
# Country                        American Samoa
# Capital                             Pago Pago
# Continent                             Oceania
# 2022 Population                       44273.0
# 2020 Population                       46189.0
# 2015 Population                       51368.0
# 2010 Population                       54849.0
# 2000 Population                       58230.0
# 1990 Population                       47818.0
# 1980 Population                       32886.0
# 1970 Population                       27075.0
# Area (km²)                              199.0
# Density (per km²)                    222.4774
# Growth Rate                            0.9831
# World Population Percentage               0.0
# Name: 3, dtype: object

# %%
df[df['Capital']=='Kabul']
# Out:
#    Rank CCA3      Country Capital Continent  2022 Population  2020 Population  \
# 0    36  AFG  Afghanistan   Kabul      Asia       41128771.0       38972230.0
#
#    2015 Population  2010 Population  2000 Population  1990 Population  \
# 0       33753499.0       28189672.0       19542982.0       10694796.0
#
#    1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 0       12486631.0       10752971.0    652230.0            63.0587
#
#    Growth Rate  World Population Percentage
# 0       1.0257                         0.52

# %%
df1=df[df['Rank']>=220]
df_sorted = df1.sort_values(by="Rank", ascending=True)
print(df_sorted)
# Out:
#      Rank CCA3                    Country       Capital      Continent  \
# 176   220  MAF               Saint Martin       Marigot  North America
# 28    221  VGB     British Virgin Islands     Road Town  North America
# 157   222  PLW                      Palau     Ngerulmud        Oceania
# 44    223  COK               Cook Islands        Avarua        Oceania
# 6     224  AIA                   Anguilla    The Valley  North America
# 142   225  NRU                      Nauru         Yaren        Oceania
# 229   226  WLF          Wallis and Futuna      Mata-Utu        Oceania
# 216   227  TUV                     Tuvalu      Funafuti        Oceania
# 173   228  BLM           Saint Barthelemy      Gustavia  North America
# 177   229  SPM  Saint Pierre and Miquelon  Saint-Pierre  North America
# 137   230  MSR                 Montserrat        Brades  North America
# 64    231  FLK           Falkland Islands       Stanley  South America
# ...

# %%
df[df['Country'].str.contains('United')]
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219        9441129.0        9287289.0        8916899.0        8481771.0
# 220       67508936.0       67059474.0       65224364.0       62760039.0
# 221      338289857.0      335942003.0      324607776.0      311182845.0
# 222          99465.0         100442.0         102803.0         106142.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219        3275333.0        1900151.0        1014048.0         298084.0
# ...

# %%
specific_continents = ['Asia','Africa']

df1=df[df['Continent'].isin(specific_continents)]
df_sorted = df1.sort_values(by="Rank", ascending=True)
print(df_sorted['2022 Population'])
# Out:
# 41     1.425887e+09
# 92     1.417173e+09
# 93     2.755013e+08
# 156    2.358249e+08
# 149    2.185412e+08
#            ...
# 123    5.237870e+05
# 29     4.490020e+05
# 130    3.261010e+05
# 181    2.273800e+05
# 185    1.071180e+05
# Name: 2022 Population, Length: 107, dtype: float64

# %%
df2 = df.set_index('Country')
df2
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
df2.filter(items = ['Continent'])
# Out:
#                   Continent
# Country
# Afghanistan            Asia
# Albania              Europe
# Algeria              Africa
# American Samoa      Oceania
# Andorra              Europe
# ...                     ...
# Wallis and Futuna   Oceania
# Western Sahara       Africa
# Yemen                  Asia
# Zambia               Africa
# Zimbabwe             Africa
#
# [234 rows x 1 columns]

# %%
df2.filter(items = ['Zimbabwe'], axis = 0)
# Out:
#           Rank CCA3 Capital Continent  2022 Population  2020 Population  \
# Zimbabwe    74  ZWE  Harare    Africa       16320537.0       15669666.0
#
#           2015 Population  2010 Population  2000 Population  1990 Population  \
# Zimbabwe       14154937.0       12839771.0       11834676.0       10113893.0
#
#           1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# Zimbabwe        7049926.0        5202918.0    390757.0            41.7665
#
#           Growth Rate  World Population Percentage
# Zimbabwe       1.0204                          0.2

# %%
df2.loc['United States']
# Out:
# Rank                                          3
# CCA3                                        USA
# Capital                        Washington, D.C.
# Continent                         North America
# 2022 Population                     338289857.0
# 2020 Population                     335942003.0
# 2015 Population                     324607776.0
# 2010 Population                     311182845.0
# 2000 Population                     282398554.0
# 1990 Population                     248083732.0
# 1980 Population                     223140018.0
# 1970 Population                     200328340.0
# Area (km²)                            9372610.0
# Density (per km²)                       36.0935
# Growth Rate                              1.0038
# World Population Percentage                4.24
# Name: United States, dtype: object

# %%
df2.iloc[3]
# Out:
# Rank                                 213
# CCA3                                 ASM
# Capital                        Pago Pago
# Continent                        Oceania
# 2022 Population                  44273.0
# 2020 Population                  46189.0
# 2015 Population                  51368.0
# 2010 Population                  54849.0
# 2000 Population                  58230.0
# 1990 Population                  47818.0
# 1980 Population                  32886.0
# 1970 Population                  27075.0
# Area (km²)                         199.0
# Density (per km²)               222.4774
# Growth Rate                       0.9831
# World Population Percentage          0.0
# Name: American Samoa, dtype: object

# %%
df[df['Rank'] < 10].sort_values(by=['Continent','Country'],ascending=[False,True])
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 27      7  BRA         Brazil          Brasilia  South America
# 221     3  USA  United States  Washington, D.C.  North America
# 171     9  RUS         Russia            Moscow         Europe
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 27      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# 221     3.382899e+08     3.359420e+08     3.246078e+08     3.111828e+08
# 171     1.447133e+08     1.456173e+08     1.446684e+08     1.432426e+08
# ...

# %%
df["Rank"].max()
# Out:
# 234

# %%
highest = df.loc[df["Rank"].idxmax()]
print(highest)
# Out:
# Rank                                    234
# CCA3                                    VAT
# Country                        Vatican City
# Capital                        Vatican City
# Continent                            Europe
# 2022 Population                       510.0
# 2020 Population                       520.0
# 2015 Population                       564.0
# 2010 Population                       596.0
# 2000 Population                       651.0
# 1990 Population                       700.0
# 1980 Population                       733.0
# 1970 Population                       752.0
# Area (km²)                              1.0
# Density (per km²)                     510.0
# Growth Rate                           0.998
# World Population Percentage             0.0
# Name: 226, dtype: object

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(df["Growth Rate"], df["Rank"])
plt.title("Rank per Growth Rate")
plt.xlabel("Growth")
plt.ylabel("Rank")
plt.show()

# %%
bd = df[df["Country"] == "Bangladesh"]

inc=bd['2022 Population']-bd['2020 Population']
print(inc)
# Out:
# 16    3765421.0
# dtype: float64

# %%
df.reset_index(inplace = True)

# %%
df.set_index(['Continent','Country'], inplace=True)

# %%
df.sort_index()
# Out:
#                             index  Rank CCA3      Capital  2022 Population  \
# Continent     Country
# Africa        Algeria           2    34  DZA      Algiers       44903225.0
#               Angola            5    42  AGO       Luanda       35588987.0
#               Benin            21    77  BEN   Porto-Novo       13352864.0
#               Botswana         26   144  BWA     Gaborone        2630296.0
#               Burkina Faso     31    58  BFA  Ouagadougou       22673762.0
# ...                           ...   ...  ...          ...              ...
# South America Paraguay        161   109  PRY     Asunción        6780744.0
#               Peru            162    44  PER         Lima       34049588.0
#               Suriname        199   170  SUR   Paramaribo         618040.0
#               Uruguay         223   133  URY   Montevideo        3422794.0
#               Venezuela       227    51  VEN      Caracas       28301696.0
#
# ...

# %%
df.reset_index(inplace = True)
df
# Out:
#      level_0 Continent            Country  index  Rank CCA3           Capital  \
# 0          0      Asia        Afghanistan      0    36  AFG             Kabul
# 1          1    Europe            Albania      1   138  ALB            Tirana
# 2          2    Africa            Algeria      2    34  DZA           Algiers
# 3          3   Oceania     American Samoa      3   213  ASM         Pago Pago
# 4          4    Europe            Andorra      4   203  AND  Andorra la Vella
# ..       ...       ...                ...    ...   ...  ...               ...
# 229      229   Oceania  Wallis and Futuna    229   226  WLF          Mata-Utu
# 230      230    Africa     Western Sahara    230   172  ESH          El Aaiún
# 231      231      Asia              Yemen    231    46  YEM             Sanaa
# 232      232    Africa             Zambia    232    63  ZMB            Lusaka
# 233      233    Africa           Zimbabwe    233    74  ZWE            Harare
#
# ...

# %%
df=pd.read_csv('/content/world_population.csv')

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...
